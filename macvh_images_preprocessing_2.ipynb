# %%
from tensorflow.keras.preprocessing.image import smart_resize
import numpy as np
# Пример функции, которая масштабирует изображение без искажений
def preprocess_image(image, size):
    return smart_resize(image, (size[0], size[1]))  # 0 - h, 1 - w

# %%
import os
import pandas as pd
import shutil
from PIL import Image

# Пути
images_dir = os.path.join(os.getcwd(), 'Military and Civilian Vehicles Classification', 'Images')  # Папка с исходными изображениями
labels_csv_path_train = os.path.join(os.getcwd(), 'Military and Civilian Vehicles Classification', 'Labels', 'CSV Format', 'train_labels.csv')  
labels_csv_path_test  = os.path.join(os.getcwd(), 'Military and Civilian Vehicles Classification', 'Labels', 'CSV Format', 'test_labels.csv')  
output_path_train = os.path.join(os.getcwd(), 'dataset_temp', 'train')  # Папка для сохранения изображений по классам
output_path_test  = os.path.join(os.getcwd(), 'dataset_temp', 'test')
target_size = (256, 256)  # Задаем целевое разрешение (ширина, высота)


def process_csv_file(csv_path, output_path, size_tuple):
    # Создаем выходную папку, если её нет
    os.makedirs(output_path, exist_ok=True)

    # Загружаем CSV файл
    data = pd.read_csv(csv_path)

    # Проходим по каждой строке CSV файла
    for _, row in data.iterrows():
        # Получаем имя файла и класс
        filename = row['filename']
        class_name = str(row['class'])  # Преобразуем класс в строку, если он числовой
        
        # Путь к исходному изображению
        src_path = os.path.join(images_dir, filename)
        
        # Путь к папке класса и создаем её, если она не существует
        class_dir = os.path.join(output_path, class_name)
        os.makedirs(class_dir, exist_ok=True)
        
        # Путь к месту назначения
        dst_path = os.path.join(class_dir, filename)

        # Проверка на наличие файла в целевой папке
        if os.path.exists(dst_path):
            print(f"Файл {filename} уже существует в {class_dir}, пропускаем.")
            continue  # Пропускаем обработку и переходим к следующему изображению

        # Открываем изображение и изменяем размер
        try:
            with Image.open(src_path) as img:
                # Преобразуем изображение в RGB, если оно имеет другую цветовую модель
                # img = img.convert("RGB")
                # img.thumbnail((256, 256))
                # Преобразуем изображение в массив и применяем smart_resize
                # img_array = np.array(img)
                # resized_array = smart_resize(img_array, target_size)
                # Преобразуем тензор в формат uint8, масштабируя его до 0-255
                # resized_array = (resized_array * 255).astype(np.uint8)
                # Преобразуем обратно в PIL.Image для сохранения
                # resized_img = Image.fromarray(resized_array)
                img.save(dst_path)  # Сохраняем изображение с новым разрешением
        except Exception as e:
            print(f"Ошибка при обработке {filename}: {e}")

    print("Изображения успешно скопированы с заданным разрешением в папки классов.")

# %%
process_csv_file(csv_path=labels_csv_path_train, output_path=output_path_train, size_tuple=target_size)
process_csv_file(csv_path=labels_csv_path_test,  output_path=output_path_test,  size_tuple=target_size)
# Out:
# Файл 000_14M0LD-e1525732547750-400x250.jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 0158.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian aircraft, пропускаем.
# Файл 0158.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian aircraft, пропускаем.
# Файл 0158.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian aircraft, пропускаем.
# Файл 0158.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian aircraft, пропускаем.
# Файл 0158.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian aircraft, пропускаем.
# Файл 0158.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian aircraft, пропускаем.
# Файл 0158.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian aircraft, пропускаем.
# Файл 0158.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian aircraft, пропускаем.
# Файл 0158.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian aircraft, пропускаем.
# Файл 03-Aerolineas-Argentinas-Comet-4-AI-PM-1959-0516-Marvin-G-Goldman-Colln.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian aircraft, пропускаем.
# Файл 03helicopters2-span-articleLarge.jpg уже существует в d:\AVClassificator\dataset_temp\train\military helicopter, пропускаем.
# Файл 03helicopters2-span-articleLarge.jpg уже существует в d:\AVClassificator\dataset_temp\train\military helicopter, пропускаем.
# Файл 03helicopters2-span-articleLarge.jpg уже существует в d:\AVClassificator\dataset_temp\train\military helicopter, пропускаем.
# Файл 071917_0109_redchinacon4.jpg уже существует в d:\AVClassificator\dataset_temp\train\military truck, пропускаем.
# Файл 071917_0109_redchinacon4.jpg уже существует в d:\AVClassificator\dataset_temp\train\military truck, пропускаем.
# Файл 071917_0109_redchinacon4.jpg уже существует в d:\AVClassificator\dataset_temp\train\military truck, пропускаем.
# Файл 071917_0109_redchinacon4.jpg уже существует в d:\AVClassificator\dataset_temp\train\military truck, пропускаем.
# Файл 07734414.jpg уже существует в d:\AVClassificator\dataset_temp\train\military aircraft, пропускаем.
# Файл 1(1).jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 1(1).jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 1(1).jpg уже существует в d:\AVClassificator\dataset_temp\train\military truck, пропускаем.
# Файл 1(2).jpg уже существует в d:\AVClassificator\dataset_temp\train\military truck, пропускаем.
# Файл 1(3).jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian aircraft, пропускаем.
# Файл 1.-turret-1024x836.jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 10(2).jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian aircraft, пропускаем.
# Файл 10(2).jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian aircraft, пропускаем.
# Файл 10(2).jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian aircraft, пропускаем.
# Файл 10(2).jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian aircraft, пропускаем.
# Файл 10(2).jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian aircraft, пропускаем.
# Файл 10(2).jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian aircraft, пропускаем.
# Файл 10(2).jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian aircraft, пропускаем.
# Файл 10(2).jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian aircraft, пропускаем.
# Файл 10(2).jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian aircraft, пропускаем.
# Файл 10(2).jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian aircraft, пропускаем.
# Файл 10(2).jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian aircraft, пропускаем.
# Файл 10(2).jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian aircraft, пропускаем.
# Файл 10(2).jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian aircraft, пропускаем.
# Файл 10(2).jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian aircraft, пропускаем.
# Файл 10(2).jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian aircraft, пропускаем.
# Файл 10(2).jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian aircraft, пропускаем.
# Файл 10(2).jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian aircraft, пропускаем.
# Файл 10-helicopter-top-view-silhouette-cover.jpg уже существует в d:\AVClassificator\dataset_temp\train\military helicopter, пропускаем.
# Файл 10-helicopter-top-view-silhouette-cover.jpg уже существует в d:\AVClassificator\dataset_temp\train\military helicopter, пропускаем.
# Файл 10-helicopter-top-view-silhouette-cover.jpg уже существует в d:\AVClassificator\dataset_temp\train\military helicopter, пропускаем.
# Файл 10-helicopter-top-view-silhouette-cover.jpg уже существует в d:\AVClassificator\dataset_temp\train\military helicopter, пропускаем.
# Файл 10-helicopter-top-view-silhouette-cover.jpg уже существует в d:\AVClassificator\dataset_temp\train\military helicopter, пропускаем.
# Файл 10-helicopter-top-view-silhouette-cover.jpg уже существует в d:\AVClassificator\dataset_temp\train\military helicopter, пропускаем.
# Файл 10-helicopter-top-view-silhouette-cover.jpg уже существует в d:\AVClassificator\dataset_temp\train\military helicopter, пропускаем.
# Файл 10-helicopter-top-view-silhouette-cover.jpg уже существует в d:\AVClassificator\dataset_temp\train\military helicopter, пропускаем.
# Файл 10-helicopter-top-view-silhouette-cover.jpg уже существует в d:\AVClassificator\dataset_temp\train\military helicopter, пропускаем.
# Файл 10.20BEML20Multipurpose20Military20vehicle.jpg уже существует в d:\AVClassificator\dataset_temp\train\military truck, пропускаем.
# Файл 10.20BEML20Multipurpose20Military20vehicle.jpg уже существует в d:\AVClassificator\dataset_temp\train\military truck, пропускаем.
# Файл 10.20BEML20Multipurpose20Military20vehicle.jpg уже существует в d:\AVClassificator\dataset_temp\train\military truck, пропускаем.
# Файл 10.20BEML20Multipurpose20Military20vehicle.jpg уже существует в d:\AVClassificator\dataset_temp\train\military truck, пропускаем.
# Файл 10.20BEML20Multipurpose20Military20vehicle.jpg уже существует в d:\AVClassificator\dataset_temp\train\military helicopter, пропускаем.
# Файл 10195209t2.jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 10195209t2.jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 10195209t2.jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 10195209t2.jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 104578368-GettyImages-486248033.jpg уже существует в d:\AVClassificator\dataset_temp\train\military aircraft, пропускаем.
# Файл 1054465381.jpg уже существует в d:\AVClassificator\dataset_temp\train\military truck, пропускаем.
# Файл 106952-cars.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian car, пропускаем.
# Файл 106952-cars.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian car, пропускаем.
# Файл 10l-image-VT4.jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 11-9.jpg уже существует в d:\AVClassificator\dataset_temp\train\military truck, пропускаем.
# Файл 11.jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 11.jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 112119-main-image.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian car, пропускаем.
# Файл 114296202-transport-set-from-above-top-view-cute-cartoon-cars-with-shadows-modern-urban-civilian-vehicles-coll.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian car, пропускаем.
# Файл 114296202-transport-set-from-above-top-view-cute-cartoon-cars-with-shadows-modern-urban-civilian-vehicles-coll.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian car, пропускаем.
# Файл 114296202-transport-set-from-above-top-view-cute-cartoon-cars-with-shadows-modern-urban-civilian-vehicles-coll.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian car, пропускаем.
# Файл 114296202-transport-set-from-above-top-view-cute-cartoon-cars-with-shadows-modern-urban-civilian-vehicles-coll.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian car, пропускаем.
# Файл 114296202-transport-set-from-above-top-view-cute-cartoon-cars-with-shadows-modern-urban-civilian-vehicles-coll.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian car, пропускаем.
# Файл 12.jpg уже существует в d:\AVClassificator\dataset_temp\train\military truck, пропускаем.
# Файл 1200px-ALCOB_Ashok_Leyland_Corporate_Building_in_Guindy2C_Chennai.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian car, пропускаем.
# Файл 1200px-ALCOB_Ashok_Leyland_Corporate_Building_in_Guindy2C_Chennai.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian car, пропускаем.
# Файл 1200px-ALCOB_Ashok_Leyland_Corporate_Building_in_Guindy2C_Chennai.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian car, пропускаем.
# Файл 1200px-ALCOB_Ashok_Leyland_Corporate_Building_in_Guindy2C_Chennai.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian car, пропускаем.
# Файл 1200px-ALCOB_Ashok_Leyland_Corporate_Building_in_Guindy2C_Chennai.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian car, пропускаем.
# Файл 1200px-F-35A_flight.jpg уже существует в d:\AVClassificator\dataset_temp\train\military aircraft, пропускаем.
# Файл 1200px-F-35A_flight.jpg уже существует в d:\AVClassificator\dataset_temp\train\military aircraft, пропускаем.
# Файл 1200px-F-35A_flight.jpg уже существует в d:\AVClassificator\dataset_temp\train\military aircraft, пропускаем.
# Файл 1200px-Leopard_2_A5_der_Bundeswehr.jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 1200px-Leopard_2_A5_der_Bundeswehr.jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 1200px-N535US_281227479809329.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian aircraft, пропускаем.
# Файл 1200px-OT-64_SKOT.jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 1200px-Ram_II_tank_Base_Borden_front.jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 1200px-Waymo_Chrysler_Pacifica_in_Los_Altos2C_2017.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian car, пропускаем.
# Файл 1200px-Waymo_Chrysler_Pacifica_in_Los_Altos2C_2017.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian car, пропускаем.
# Файл 1200px-Waymo_Chrysler_Pacifica_in_Los_Altos2C_2017.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian car, пропускаем.
# Файл 12022557_1631786917110661_1189723371028766091_o.jpg уже существует в d:\AVClassificator\dataset_temp\train\military helicopter, пропускаем.
# Файл 120249379-military-tank-side-and-top-view-isolated-on-white-3d-rendering.jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 120249435-military-tank-side-and-top-view-isolated-on-white-3d-rendering.jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 120249460-military-tank-side-and-top-view-isolated-on-white-3d-rendering.jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 120249525-military-tank-side-and-top-view-isolated-on-white-3d-rendering.jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 120312_6606.jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 120312_6606.jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 120696131-military-tank-side-and-top-view-isolated-on-white-3d-rendering.jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 120696132-military-tank-side-and-top-view-isolated-on-white-3d-rendering.jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 1305552-bigthumbnail.jpg уже существует в d:\AVClassificator\dataset_temp\train\military aircraft, пропускаем.
# Файл 13625510-high-detailed-vector-illustration-of-a-modern-military-airplane-top-view-with-six-camouflage-pattern.jpg уже существует в d:\AVClassificator\dataset_temp\train\military aircraft, пропускаем.
# Файл 13625510-high-detailed-vector-illustration-of-a-modern-military-airplane-top-view-with-six-camouflage-pattern.jpg уже существует в d:\AVClassificator\dataset_temp\train\military aircraft, пропускаем.
# Файл 13625510-high-detailed-vector-illustration-of-a-modern-military-airplane-top-view-with-six-camouflage-pattern.jpg уже существует в d:\AVClassificator\dataset_temp\train\military aircraft, пропускаем.
# Файл 13625510-high-detailed-vector-illustration-of-a-modern-military-airplane-top-view-with-six-camouflage-pattern.jpg уже существует в d:\AVClassificator\dataset_temp\train\military aircraft, пропускаем.
# Файл 13625510-high-detailed-vector-illustration-of-a-modern-military-airplane-top-view-with-six-camouflage-pattern.jpg уже существует в d:\AVClassificator\dataset_temp\train\military aircraft, пропускаем.
# Файл 136926792_15169696659001n.jpg уже существует в d:\AVClassificator\dataset_temp\train\military truck, пропускаем.
# Файл 136926792_15169696817431n.jpg уже существует в d:\AVClassificator\dataset_temp\train\military truck, пропускаем.
# Файл 136926792_15169696817431n.jpg уже существует в d:\AVClassificator\dataset_temp\train\military truck, пропускаем.
# Файл 136926792_15169696817431n.jpg уже существует в d:\AVClassificator\dataset_temp\train\military truck, пропускаем.
# Файл 1373df35948c7e058aced5480c989885.jpg уже существует в d:\AVClassificator\dataset_temp\train\military truck, пропускаем.
# Файл 1391360424loadout_abramsm1a1.jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 1450501964_nBLkGF_russia-missile-shutterstock-870.jpg уже существует в d:\AVClassificator\dataset_temp\train\military truck, пропускаем.
# Файл 1450501964_nBLkGF_russia-missile-shutterstock-870.jpg уже существует в d:\AVClassificator\dataset_temp\train\military truck, пропускаем.
# Файл 1463pcs-Compatible-font-b-Legoinglys-b-font-Military-font-b-Tank-b-font-Building-Blocks-M1a2.jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 1495315715008.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian aircraft, пропускаем.
# Файл 1495315715008.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian aircraft, пропускаем.
# Файл 1530384251-6388.jpg уже существует в d:\AVClassificator\dataset_temp\train\military aircraft, пропускаем.
# Файл 1578086878_6107673115001_6107662231001-vs.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian car, пропускаем.
# Файл 160727135112-iconic-aircraft-a300-paris-airshow--88555561-super-169.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian aircraft, пропускаем.
# Файл 161356-indian-army-tank.jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 16582468309620761590.jpg уже существует в d:\AVClassificator\dataset_temp\train\military truck, пропускаем.
# Файл 169007_one.jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 16army.jpg уже существует в d:\AVClassificator\dataset_temp\train\military truck, пропускаем.
# Файл 16army.jpg уже существует в d:\AVClassificator\dataset_temp\train\military truck, пропускаем.
# Файл 177567940.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian car, пропускаем.
# Файл 177567940.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian car, пропускаем.
# Файл 177567940.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian car, пропускаем.
# Файл 177567940.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian car, пропускаем.
# Файл 177567940.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian car, пропускаем.
# Файл 177567940.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian car, пропускаем.
# Файл 177567940.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian car, пропускаем.
# Файл 177567940.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian car, пропускаем.
# Файл 177567940.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian car, пропускаем.
# Файл 177567940.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian car, пропускаем.
# Файл 177567940.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian car, пропускаем.
# Файл 17c3e965dc15750e0267c140d9ff1597.jpg уже существует в d:\AVClassificator\dataset_temp\train\military truck, пропускаем.
# Файл 180705-embraer-630x378.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian aircraft, пропускаем.
# Файл 18669083_303.jpg уже существует в d:\AVClassificator\dataset_temp\train\military aircraft, пропускаем.
# Файл 18669083_303.jpg уже существует в d:\AVClassificator\dataset_temp\train\military aircraft, пропускаем.
# Файл 18669083_303.jpg уже существует в d:\AVClassificator\dataset_temp\train\military aircraft, пропускаем.
# Файл 18891900-10155147445475944-2966483851403758582-o-1518561682.jpg уже существует в d:\AVClassificator\dataset_temp\train\military aircraft, пропускаем.
# Файл 18891900-10155147445475944-2966483851403758582-o-1518561682.jpg уже существует в d:\AVClassificator\dataset_temp\train\military aircraft, пропускаем.
# Файл 18891900-10155147445475944-2966483851403758582-o-1518561682.jpg уже существует в d:\AVClassificator\dataset_temp\train\military aircraft, пропускаем.
# Файл 191020-fort-stewart-bradley-fighting-vehicle-cs-1233p_31f3f147195974dd5dc2d0262c8e7688.jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 191020-fort-stewart-bradley-fighting-vehicle-cs-1233p_31f3f147195974dd5dc2d0262c8e7688.jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 191205-TH-CH-tanks-1000.jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 191211-M-GL635-006.jpg уже существует в d:\AVClassificator\dataset_temp\train\military truck, пропускаем.
# Файл 1930s-40s-6-x-4-Repro-German-RP-Panzer.jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 19878346-3d-of-various-isolated-cars-top-view-position.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian car, пропускаем.
# Файл 19878346-3d-of-various-isolated-cars-top-view-position.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian car, пропускаем.
# Файл 19878346-3d-of-various-isolated-cars-top-view-position.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian car, пропускаем.
# Файл 19878346-3d-of-various-isolated-cars-top-view-position.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian car, пропускаем.
# Файл 19878346-3d-of-various-isolated-cars-top-view-position.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian car, пропускаем.
# Файл 19878346-3d-of-various-isolated-cars-top-view-position.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian car, пропускаем.
# Файл 19878346-3d-of-various-isolated-cars-top-view-position.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian car, пропускаем.
# Файл 19878346-3d-of-various-isolated-cars-top-view-position.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian car, пропускаем.
# Файл 19878346-3d-of-various-isolated-cars-top-view-position.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian car, пропускаем.
# Файл 19878346-3d-of-various-isolated-cars-top-view-position.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian car, пропускаем.
# Файл 19878346-3d-of-various-isolated-cars-top-view-position.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian car, пропускаем.
# Файл 19_04_2019_013_004.jpg уже существует в d:\AVClassificator\dataset_temp\train\military truck, пропускаем.
# Файл 19_04_2019_013_004.jpg уже существует в d:\AVClassificator\dataset_temp\train\military truck, пропускаем.
# Ошибка при обработке 1convoy.jpg: [Errno 2] No such file or directory: 'D:\\AVClassificator\\Military and Civilian Vehicles Classification\\Images\\1convoy.jpg'
# Файл 1d98a84b05bcc76dc3b12b7bc183d31e.jpg уже существует в d:\AVClassificator\dataset_temp\train\military aircraft, пропускаем.
# Файл 1M1A5533.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian car, пропускаем.
# Файл 1st_Armoured_Div_28AWM_02547329.jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 1st_Armoured_Div_28AWM_02547329.jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 1st_Armoured_Div_28AWM_02547329.jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 1st_Fighter_Wing_hosts_coalition_aerial_exercise_28329.jpg уже существует в d:\AVClassificator\dataset_temp\train\military aircraft, пропускаем.
# Файл 1st_Fighter_Wing_hosts_coalition_aerial_exercise_28329.jpg уже существует в d:\AVClassificator\dataset_temp\train\military aircraft, пропускаем.
# Файл 1st_Fighter_Wing_hosts_coalition_aerial_exercise_28329.jpg уже существует в d:\AVClassificator\dataset_temp\train\military aircraft, пропускаем.
# Файл 1_ms_1.jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 1_ms_1.jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 1_ms_1.jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 2-Figure2-1.jpg уже существует в d:\AVClassificator\dataset_temp\train\military helicopter, пропускаем.
# Файл 20110312-_1481193687.jpg уже существует в d:\AVClassificator\dataset_temp\train\military truck, пропускаем.
# Файл 2014chilec130aircraft-1575947699.jpg уже существует в d:\AVClassificator\dataset_temp\train\military aircraft, пропускаем.
# Файл 2019-05-19-PSC_Tiger1-03.jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 2019_1largeimg23_Jan_2019_135130392.jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 2197-Panther-Action-Shot__66292.1533765540.jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 220px-2.5_ton_28229.jpg уже существует в d:\AVClassificator\dataset_temp\train\military truck, пропускаем.
# Файл 220px-IA_T-90_in_action.jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 220px-IA_T-90_in_action.jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 220px-IA_T-90_in_action.jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 220px-IA_T-90_in_action.jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 235595341.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian aircraft, пропускаем.
# Файл 24d8870e-d826-4cbb-8087-f6ff7e7c3429.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian car, пропускаем.
# Файл 255954469.jpg уже существует в d:\AVClassificator\dataset_temp\train\military truck, пропускаем.
# Файл 255954469.jpg уже существует в d:\AVClassificator\dataset_temp\train\military truck, пропускаем.
# Файл 255954469.jpg уже существует в d:\AVClassificator\dataset_temp\train\military truck, пропускаем.
# Файл 255954469.jpg уже существует в d:\AVClassificator\dataset_temp\train\military truck, пропускаем.
# Файл 26bhishma01.jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 281eb17fac4c474a7309bddf4d5a004c.jpg уже существует в d:\AVClassificator\dataset_temp\train\military helicopter, пропускаем.
# Файл 2848285941.jpg уже существует в d:\AVClassificator\dataset_temp\train\military aircraft, пропускаем.
# Файл 289432024.jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 29174d68bcf3f432ec28bb18e0b170dd.jpg уже существует в d:\AVClassificator\dataset_temp\train\military helicopter, пропускаем.
# Файл 29174d68bcf3f432ec28bb18e0b170dd.jpg уже существует в d:\AVClassificator\dataset_temp\train\military helicopter, пропускаем.
# Файл 29174d68bcf3f432ec28bb18e0b170dd.jpg уже существует в d:\AVClassificator\dataset_temp\train\military helicopter, пропускаем.
# Файл 29174d68bcf3f432ec28bb18e0b170dd.jpg уже существует в d:\AVClassificator\dataset_temp\train\military helicopter, пропускаем.
# Файл 29174d68bcf3f432ec28bb18e0b170dd.jpg уже существует в d:\AVClassificator\dataset_temp\train\military helicopter, пропускаем.
# Файл 29174d68bcf3f432ec28bb18e0b170dd.jpg уже существует в d:\AVClassificator\dataset_temp\train\military helicopter, пропускаем.
# Файл 2a3a538e8ed338492a170d234a569836.jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 2viewf4u.jpg уже существует в d:\AVClassificator\dataset_temp\train\military aircraft, пропускаем.
# Файл 3-cars-mini-1.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian car, пропускаем.
# Файл 3-cars-mini-1.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian car, пропускаем.
# Файл 3-helicopters-from-top-view-top-womens-premium-longsleeve-shirt.jpg уже существует в d:\AVClassificator\dataset_temp\train\military helicopter, пропускаем.
# Файл 3-helicopters-from-top-view-top-womens-premium-longsleeve-shirt.jpg уже существует в d:\AVClassificator\dataset_temp\train\military helicopter, пропускаем.
# Файл 300px-Battle_of_Britain_Memorial_Flight_Members27_day_2018_MOD_45164718.jpg уже существует в d:\AVClassificator\dataset_temp\train\military aircraft, пропускаем.
# Файл 3169218494_3b4c15ea9b.jpg уже существует в d:\AVClassificator\dataset_temp\train\military truck, пропускаем.
# Файл 3169218494_3b4c15ea9b.jpg уже существует в d:\AVClassificator\dataset_temp\train\military truck, пропускаем.
# Файл 336487312.jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 347PCS-Technik-Military-Tank-Building-Blocks-Model-Figures-Compatible-legoingly-Army-WW2-Soldier-Police-Weapon-Bricks.jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 375990-alexfas01.jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 377306_cars-top-view-png.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian car, пропускаем.
# Файл 377306_cars-top-view-png.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian car, пропускаем.
# Файл 377312_cars-top-view-png.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian car, пропускаем.
# Файл 377312_cars-top-view-png.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian car, пропускаем.
# Файл 377312_cars-top-view-png.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian car, пропускаем.
# Файл 377312_cars-top-view-png.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian car, пропускаем.
# Файл 377312_cars-top-view-png.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian car, пропускаем.
# Файл 377312_cars-top-view-png.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian car, пропускаем.
# Файл 377312_cars-top-view-png.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian car, пропускаем.
# Файл 3A0A3130.jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 3b7dad11236005.560f46bd8a54b.jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 3c605a677d0a5e06082ffec2983baf48-scaled.jpg уже существует в d:\AVClassificator\dataset_temp\train\military aircraft, пропускаем.
# Файл 3c605a677d0a5e06082ffec2983baf48-scaled.jpg уже существует в d:\AVClassificator\dataset_temp\train\military aircraft, пропускаем.
# Файл 3c605a677d0a5e06082ffec2983baf48-scaled.jpg уже существует в d:\AVClassificator\dataset_temp\train\military aircraft, пропускаем.
# Файл 3c605a677d0a5e06082ffec2983baf48-scaled.jpg уже существует в d:\AVClassificator\dataset_temp\train\military aircraft, пропускаем.
# Файл 3d-image-of-military-aircraft-top-front-and-side-vector-20835024.jpg уже существует в d:\AVClassificator\dataset_temp\train\military aircraft, пропускаем.
# Файл 3d-image-of-military-aircraft-top-front-and-side-vector-20835024.jpg уже существует в d:\AVClassificator\dataset_temp\train\military aircraft, пропускаем.
# Файл 3fe4e289078edd29945a31eb33ca34ea.jpg уже существует в d:\AVClassificator\dataset_temp\train\military helicopter, пропускаем.
# Файл 3fe4e289078edd29945a31eb33ca34ea.jpg уже существует в d:\AVClassificator\dataset_temp\train\military helicopter, пропускаем.
# Файл 3fe4e289078edd29945a31eb33ca34ea.jpg уже существует в d:\AVClassificator\dataset_temp\train\military helicopter, пропускаем.
# Файл 3XeNNMeIhplCPzD7iPw7HiYky3HEn5xAmxTX2jzi.jpg уже существует в d:\AVClassificator\dataset_temp\train\military helicopter, пропускаем.
# Файл 3_img19419092943.jpg уже существует в d:\AVClassificator\dataset_temp\train\military truck, пропускаем.
# Файл 3_img19419092943.jpg уже существует в d:\AVClassificator\dataset_temp\train\military truck, пропускаем.
# Файл 3_img19419092943.jpg уже существует в d:\AVClassificator\dataset_temp\train\military truck, пропускаем.
# Файл 3_img19419092943.jpg уже существует в d:\AVClassificator\dataset_temp\train\military truck, пропускаем.
# Файл 4-C-17-Globemaster.jpg уже существует в d:\AVClassificator\dataset_temp\train\military aircraft, пропускаем.
# Файл 4-C-17-Globemaster.jpg уже существует в d:\AVClassificator\dataset_temp\train\military aircraft, пропускаем.
# Файл 4-C-17-Globemaster.jpg уже существует в d:\AVClassificator\dataset_temp\train\military aircraft, пропускаем.
# Файл 4-C-17-Globemaster.jpg уже существует в d:\AVClassificator\dataset_temp\train\military aircraft, пропускаем.
# Файл 4-C-17-Globemaster.jpg уже существует в d:\AVClassificator\dataset_temp\train\military aircraft, пропускаем.
# Файл 4-C-17-Globemaster.jpg уже существует в d:\AVClassificator\dataset_temp\train\military aircraft, пропускаем.
# Файл 4-C-17-Globemaster.jpg уже существует в d:\AVClassificator\dataset_temp\train\military aircraft, пропускаем.
# Файл 400a18e0f076bc6426c17acd885adab9.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian aircraft, пропускаем.
# Файл 400a18e0f076bc6426c17acd885adab9.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian aircraft, пропускаем.
# Файл 400a18e0f076bc6426c17acd885adab9.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian aircraft, пропускаем.
# Файл 400px-AH-1Z_Line_Drawing.svg.jpg уже существует в d:\AVClassificator\dataset_temp\train\military helicopter, пропускаем.
# Файл 400px-MH-53J_Pave_Low_Line_Drawing.svg.jpg уже существует в d:\AVClassificator\dataset_temp\train\military helicopter, пропускаем.
# Файл 400px-MH-53J_Pave_Low_Line_Drawing.svg.jpg уже существует в d:\AVClassificator\dataset_temp\train\military helicopter, пропускаем.
# Файл 44247-pakistan25252520super25252520league-20180322094007.jpg уже существует в d:\AVClassificator\dataset_temp\train\military helicopter, пропускаем.
# Файл 44b8486523985cb0b70763d7281fa6fe.jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 44b8486523985cb0b70763d7281fa6fe.jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 44b8486523985cb0b70763d7281fa6fe.jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 44b8486523985cb0b70763d7281fa6fe.jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 467a6c6b2a64d7360f72af5b467d72b5.jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 467a6c6b2a64d7360f72af5b467d72b5.jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 467a6c6b2a64d7360f72af5b467d72b5.jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 472c822e025b2c86bdc5279d668e4e1b.jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 472c822e025b2c86bdc5279d668e4e1b.jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 481593_5_.jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 4f20b1886c988607db2ef177f3e986c76a28860655bb09687fe9285f9024a078.jpg уже существует в d:\AVClassificator\dataset_temp\train\military aircraft, пропускаем.
# Файл 4f20b1886c988607db2ef177f3e986c76a28860655bb09687fe9285f9024a078.jpg уже существует в d:\AVClassificator\dataset_temp\train\military aircraft, пропускаем.
# Файл 4f20b1886c988607db2ef177f3e986c76a28860655bb09687fe9285f9024a078.jpg уже существует в d:\AVClassificator\dataset_temp\train\military aircraft, пропускаем.
# Файл 4f20b1886c988607db2ef177f3e986c76a28860655bb09687fe9285f9024a078.jpg уже существует в d:\AVClassificator\dataset_temp\train\military aircraft, пропускаем.
# Файл 4f20b1886c988607db2ef177f3e986c76a28860655bb09687fe9285f9024a078.jpg уже существует в d:\AVClassificator\dataset_temp\train\military aircraft, пропускаем.
# Файл 4Star2.jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 5-image-Boeing-787-8.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian aircraft, пропускаем.
# Файл 5-image-Boeing-787-8.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian aircraft, пропускаем.
# Файл 5-image-Boeing-787-8.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian aircraft, пропускаем.
# Файл 500_F_142453719_Bz5Thl4zdwY4StDH6UeJSFbqAYY8iUhk.jpg уже существует в d:\AVClassificator\dataset_temp\train\military helicopter, пропускаем.
# Файл 500_F_142453719_Bz5Thl4zdwY4StDH6UeJSFbqAYY8iUhk.jpg уже существует в d:\AVClassificator\dataset_temp\train\military helicopter, пропускаем.
# Файл 500_F_172517614_NFV6y4bNyqTkjuuWoP38T2zM1FRx811L.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian car, пропускаем.
# Файл 500_F_172517614_NFV6y4bNyqTkjuuWoP38T2zM1FRx811L.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian car, пропускаем.
# Файл 500_F_172517614_NFV6y4bNyqTkjuuWoP38T2zM1FRx811L.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian car, пропускаем.
# Файл 500_F_172517614_NFV6y4bNyqTkjuuWoP38T2zM1FRx811L.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian car, пропускаем.
# Файл 500_F_172517614_NFV6y4bNyqTkjuuWoP38T2zM1FRx811L.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian car, пропускаем.
# Файл 500_F_172517614_NFV6y4bNyqTkjuuWoP38T2zM1FRx811L.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian car, пропускаем.
# Файл 500_F_172517614_NFV6y4bNyqTkjuuWoP38T2zM1FRx811L.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian car, пропускаем.
# Файл 500_F_172517614_NFV6y4bNyqTkjuuWoP38T2zM1FRx811L.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian car, пропускаем.
# Файл 500_F_172517614_NFV6y4bNyqTkjuuWoP38T2zM1FRx811L.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian car, пропускаем.
# Файл 500_F_172517614_NFV6y4bNyqTkjuuWoP38T2zM1FRx811L.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian car, пропускаем.
# Файл 500_F_172517614_NFV6y4bNyqTkjuuWoP38T2zM1FRx811L.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian car, пропускаем.
# Файл 500_F_172929710_VNUqrsIUl9JB6STeuGMKuEAWAfLM2uFO.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian aircraft, пропускаем.
# Файл 500_F_172929710_VNUqrsIUl9JB6STeuGMKuEAWAfLM2uFO.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian aircraft, пропускаем.
# Файл 500_F_191857320_AR3d8quOJSZtaBAIcEiqctGRBUuWhUBh.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian aircraft, пропускаем.
# Файл 500_F_191857320_AR3d8quOJSZtaBAIcEiqctGRBUuWhUBh.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian aircraft, пропускаем.
# Файл 500_F_191857320_AR3d8quOJSZtaBAIcEiqctGRBUuWhUBh.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian aircraft, пропускаем.
# Файл 500_F_191857320_AR3d8quOJSZtaBAIcEiqctGRBUuWhUBh.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian aircraft, пропускаем.
# Файл 500_F_191857320_AR3d8quOJSZtaBAIcEiqctGRBUuWhUBh.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian aircraft, пропускаем.
# Файл 500_F_259615177_8xrlfGugRJSbLiKrTZn7kY1m88HxwGKu.jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 500_F_261090072_jvMsvqg6PHIqVVO6NEKE6OkfinnP58me.jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 500_F_261090158_C14ilzX0GuRffGxXHI9FeXsQhN1AhZQk.jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 5105393-1568150246.jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 51FUlbWwULL.jpg уже существует в d:\AVClassificator\dataset_temp\train\military truck, пропускаем.
# Файл 51LeXIYYTPL.jpg уже существует в d:\AVClassificator\dataset_temp\train\military truck, пропускаем.
# Файл 51qjuTYtOXL.jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 51qjuTYtOXL.jpg уже существует в d:\AVClassificator\dataset_temp\train\military truck, пропускаем.
# Файл 54672.jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 57b74d1f9de21cc9ce25cc97bdd26994.jpg уже существует в d:\AVClassificator\dataset_temp\train\military truck, пропускаем.
# Файл 57b74d1f9de21cc9ce25cc97bdd26994.jpg уже существует в d:\AVClassificator\dataset_temp\train\military truck, пропускаем.
# Файл 59c9c2bd45d2a027e83e2459.jpg уже существует в d:\AVClassificator\dataset_temp\train\military helicopter, пропускаем.
# Файл 5ab9b9ca52c65.jpg уже существует в d:\AVClassificator\dataset_temp\train\military helicopter, пропускаем.
# Файл 5ab9b9ca52c65.jpg уже существует в d:\AVClassificator\dataset_temp\train\military helicopter, пропускаем.
# Файл 5acdd7430f25430ed82aab66.jpg уже существует в d:\AVClassificator\dataset_temp\train\military aircraft, пропускаем.
# Файл 5b7b33d8e9992.image.jpg уже существует в d:\AVClassificator\dataset_temp\train\military helicopter, пропускаем.
# Файл 5cbc1eac0b29425db01d662a67d177a4_c0x0-1600x686.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian car, пропускаем.
# Файл 5d9fc272a310cf3e97a08c18.jpg уже существует в d:\AVClassificator\dataset_temp\train\military helicopter, пропускаем.
# Файл 5e33f181c464a1deb64ebd5ab1263159.image.596x842.jpg уже существует в d:\AVClassificator\dataset_temp\train\military truck, пропускаем.
# Файл 5_1024x10242x.jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 5_5_b2.jpg уже существует в d:\AVClassificator\dataset_temp\train\military helicopter, пропускаем.
# Файл 5_5_b2.jpg уже существует в d:\AVClassificator\dataset_temp\train\military helicopter, пропускаем.
# Файл 60175-izlceqjtpm-1496913217.jpg уже существует в d:\AVClassificator\dataset_temp\train\military aircraft, пропускаем.
# Файл 61535-551_grande.jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 659-88005500_20120118_240.jpg уже существует в d:\AVClassificator\dataset_temp\train\military truck, пропускаем.
# Файл 659-88005500_20120118_240.jpg уже существует в d:\AVClassificator\dataset_temp\train\military truck, пропускаем.
# Файл 688711h87f6t28.jpg уже существует в d:\AVClassificator\dataset_temp\train\military aircraft, пропускаем.
# Файл 688711h87f6t28.jpg уже существует в d:\AVClassificator\dataset_temp\train\military aircraft, пропускаем.
# Файл 688711h87f6t28.jpg уже существует в d:\AVClassificator\dataset_temp\train\military aircraft, пропускаем.
# Файл 694940094001_5841062081001_5841066057001-vs.jpg уже существует в d:\AVClassificator\dataset_temp\train\military helicopter, пропускаем.
# Файл 69727035-military-attack-helicopter-top-side-front-view-on-white-background-flat-style-vector-illustration-.jpg уже существует в d:\AVClassificator\dataset_temp\train\military helicopter, пропускаем.
# Файл 69727035-military-attack-helicopter-top-side-front-view-on-white-background-flat-style-vector-illustration-.jpg уже существует в d:\AVClassificator\dataset_temp\train\military helicopter, пропускаем.
# Файл 6c2a9d103ea506d1def34964e79475ef.jpg уже существует в d:\AVClassificator\dataset_temp\train\military aircraft, пропускаем.
# Файл 7137227-attack-helicopter.jpg уже существует в d:\AVClassificator\dataset_temp\train\military helicopter, пропускаем.
# Файл 7471fe74a6237e07d80e35483fdee302.jpg уже существует в d:\AVClassificator\dataset_temp\train\military truck, пропускаем.
# Файл 767tb-29(1).jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 799cbca6fba2aa2f02d5f45c2eedbc26.jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 799cbca6fba2aa2f02d5f45c2eedbc26.jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 799cbca6fba2aa2f02d5f45c2eedbc26.jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 7b15bc6f18e7a56e233bf9babfd4be07.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian aircraft, пропускаем.
# Файл 7b15bc6f18e7a56e233bf9babfd4be07.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian aircraft, пропускаем.
# Файл 7b15bc6f18e7a56e233bf9babfd4be07.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian aircraft, пропускаем.
# Файл 7b15bc6f18e7a56e233bf9babfd4be07.jpg уже существует в d:\AVClassificator\dataset_temp\train\civilian aircraft, пропускаем.
# Файл 7ee2a31767e0b014053b79b9213b8c2a--ww-tanks-armored-vehicles.jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 7ee2a31767e0b014053b79b9213b8c2a--ww-tanks-armored-vehicles.jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 7ee2a31767e0b014053b79b9213b8c2a--ww-tanks-armored-vehicles.jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 7EQA2ZU3WQI6THWUZEEJS4VNLI.jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 8-image-Mi-26.jpg уже существует в d:\AVClassificator\dataset_temp\train\military helicopter, пропускаем.
# Файл 8-image-Mi-26.jpg уже существует в d:\AVClassificator\dataset_temp\train\military helicopter, пропускаем.
# Файл 8.20tanks.jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 800px-ea-6bprowlerssupportingnorthernwatch-1.jpg уже существует в d:\AVClassificator\dataset_temp\train\military aircraft, пропускаем.
# Файл 807710-raf-typhoon-il76.jpg уже существует в d:\AVClassificator\dataset_temp\train\military aircraft, пропускаем.
# Файл 832-256572.jpg уже существует в d:\AVClassificator\dataset_temp\train\military truck, пропускаем.
# Файл 832-256572.jpg уже существует в d:\AVClassificator\dataset_temp\train\military truck, пропускаем.
# Файл 832-256576.jpg уже существует в d:\AVClassificator\dataset_temp\train\military truck, пропускаем.
# Файл 87374148-ladakh-india-sep-12-2017-indian-army-truck-convoy-on-narrow-road-along-indus-river-ladakh-india.jpg уже существует в d:\AVClassificator\dataset_temp\train\military truck, пропускаем.
# Файл 87374148-ladakh-india-sep-12-2017-indian-army-truck-convoy-on-narrow-road-along-indus-river-ladakh-india.jpg уже существует в d:\AVClassificator\dataset_temp\train\military truck, пропускаем.
# Файл 87374148-ladakh-india-sep-12-2017-indian-army-truck-convoy-on-narrow-road-along-indus-river-ladakh-india.jpg уже существует в d:\AVClassificator\dataset_temp\train\military truck, пропускаем.
# Файл 87374183-ladakh-india-sep-12-2017-indian-army-truck-convoy-on-narrow-road-along-indus-river-ladakh-india.jpg уже существует в d:\AVClassificator\dataset_temp\train\military truck, пропускаем.
# Файл 87374183-ladakh-india-sep-12-2017-indian-army-truck-convoy-on-narrow-road-along-indus-river-ladakh-india.jpg уже существует в d:\AVClassificator\dataset_temp\train\military truck, пропускаем.
# Файл 87374183-ladakh-india-sep-12-2017-indian-army-truck-convoy-on-narrow-road-along-indus-river-ladakh-india.jpg уже существует в d:\AVClassificator\dataset_temp\train\military truck, пропускаем.
# Файл 87374236-ladakh-india-sep-12-2017-indian-army-truck-convoy-on-narrow-road-along-indus-river-ladakh-india.jpg уже существует в d:\AVClassificator\dataset_temp\train\military truck, пропускаем.
# Файл 87461584-ladakh-india-sep-12-2017-indian-army-truck-convoy-on-narrow-road-along-indus-river-ladakh-india.jpg уже существует в d:\AVClassificator\dataset_temp\train\military truck, пропускаем.
# Файл 87461584-ladakh-india-sep-12-2017-indian-army-truck-convoy-on-narrow-road-along-indus-river-ladakh-india.jpg уже существует в d:\AVClassificator\dataset_temp\train\military truck, пропускаем.
# Файл 87461647-ladakh-india-sep-12-2017-indian-army-truck-convoy-on-narrow-road-along-indus-river-ladakh-india.jpg уже существует в d:\AVClassificator\dataset_temp\train\military truck, пропускаем.
# Файл 87461647-ladakh-india-sep-12-2017-indian-army-truck-convoy-on-narrow-road-along-indus-river-ladakh-india.jpg уже существует в d:\AVClassificator\dataset_temp\train\military truck, пропускаем.
# Файл 88518643-ladakh-india-sep-12-2017-indian-army-truck-convoy-on-narrow-road-along-indus-river-ladakh-india.jpg уже существует в d:\AVClassificator\dataset_temp\train\military truck, пропускаем.
# Файл 8aa3a35b-b68b-43eb-a8cc-c6e15fa152cfJPG.jpg уже существует в d:\AVClassificator\dataset_temp\train\military truck, пропускаем.
# Файл 8bc3fe3b-97dd-41d8-99cf-76997da75bc2-AP_Japan_US_Military_Plane_CrashJPG.jpg уже существует в d:\AVClassificator\dataset_temp\train\military aircraft, пропускаем.
# Файл 8bc3fe3b-97dd-41d8-99cf-76997da75bc2-AP_Japan_US_Military_Plane_CrashJPG.jpg уже существует в d:\AVClassificator\dataset_temp\train\military aircraft, пропускаем.
# Файл 9-3.jpg уже существует в d:\AVClassificator\dataset_temp\train\military helicopter, пропускаем.
# Файл 9-3.jpg уже существует в d:\AVClassificator\dataset_temp\train\military helicopter, пропускаем.
# Файл 91qHHhwPUYL.jpg уже существует в d:\AVClassificator\dataset_temp\train\military helicopter, пропускаем.
# Файл 91qHHhwPUYL.jpg уже существует в d:\AVClassificator\dataset_temp\train\military helicopter, пропускаем.
# Файл 91qHHhwPUYL.jpg уже существует в d:\AVClassificator\dataset_temp\train\military helicopter, пропускаем.
# Файл 91qHHhwPUYL.jpg уже существует в d:\AVClassificator\dataset_temp\train\military helicopter, пропускаем.
# Файл 92923279-military-helicopter-in-realistic-style-on-white-background-top-side-front-view-army-air-vehicle-.jpg уже существует в d:\AVClassificator\dataset_temp\train\military helicopter, пропускаем.
# Файл 92923279-military-helicopter-in-realistic-style-on-white-background-top-side-front-view-army-air-vehicle-.jpg уже существует в d:\AVClassificator\dataset_temp\train\military helicopter, пропускаем.
# Файл 93602c6f1420748ebb66eb9a64e70161.jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 93602c6f1420748ebb66eb9a64e70161.jpg уже существует в d:\AVClassificator\dataset_temp\train\military tank, пропускаем.
# Файл 93ad54c9fd3c4088adaaaff15a416fff.jpg уже существует в d:\AVClassificator\dataset_temp\train\military truck, пропускаем.
# Файл 93ad54c9fd3c4088adaaaff15a416fff.jpg уже существует в d:\AVClassificator\dataset_temp\train\military truck, пропускаем.
# ...
# Файл armored-truck-vector-mockup-clipart__k61587600.jpg уже существует в d:\AVClassificator\dataset_temp\test\military truck, пропускаем.
# Файл armored-truck-vector-mockup-clipart__k61587600.jpg уже существует в d:\AVClassificator\dataset_temp\test\military truck, пропускаем.
# Файл armored-truck-vector-mockup-clipart__k61587600.jpg уже существует в d:\AVClassificator\dataset_temp\test\military truck, пропускаем.
# Файл armoured-military-truck-manufacturers-traders-dealers-supplier-in-india-1-638.jpg уже существует в d:\AVClassificator\dataset_temp\test\military truck, пропускаем.
# Файл armoured-military-truck-manufacturers-traders-dealers-supplier-in-india-1-638.jpg уже существует в d:\AVClassificator\dataset_temp\test\military truck, пропускаем.
# Файл army23.jpg уже существует в d:\AVClassificator\dataset_temp\test\military truck, пропускаем.
# Файл image0(10).jpg уже существует в d:\AVClassificator\dataset_temp\test\civilian aircraft, пропускаем.
# Файл image0(7).jpg уже существует в d:\AVClassificator\dataset_temp\test\military helicopter, пропускаем.
# Файл image0(7).jpg уже существует в d:\AVClassificator\dataset_temp\test\military helicopter, пропускаем.
# Файл image003.jpg уже существует в d:\AVClassificator\dataset_temp\test\military tank, пропускаем.
# Файл image003.jpg уже существует в d:\AVClassificator\dataset_temp\test\military tank, пропускаем.
# Файл image10(2).jpg уже существует в d:\AVClassificator\dataset_temp\test\military tank, пропускаем.
# Файл image11(1).jpg уже существует в d:\AVClassificator\dataset_temp\test\military tank, пропускаем.
# Файл image11(2).jpg уже существует в d:\AVClassificator\dataset_temp\test\military tank, пропускаем.
# Файл image12(2).jpg уже существует в d:\AVClassificator\dataset_temp\test\military tank, пропускаем.
# Файл image13(2).jpg уже существует в d:\AVClassificator\dataset_temp\test\military tank, пропускаем.
# Файл image6.jpg уже существует в d:\AVClassificator\dataset_temp\test\military truck, пропускаем.
# Файл image6.jpg уже существует в d:\AVClassificator\dataset_temp\test\military truck, пропускаем.
# Файл image6.jpg уже существует в d:\AVClassificator\dataset_temp\test\military truck, пропускаем.
# Файл image6.jpg уже существует в d:\AVClassificator\dataset_temp\test\military truck, пропускаем.
# Файл image6.jpg уже существует в d:\AVClassificator\dataset_temp\test\military truck, пропускаем.
# Файл image6.jpg уже существует в d:\AVClassificator\dataset_temp\test\military truck, пропускаем.
# Файл image6.jpg уже существует в d:\AVClassificator\dataset_temp\test\military truck, пропускаем.
# Файл image6.jpg уже существует в d:\AVClassificator\dataset_temp\test\military truck, пропускаем.
# Файл image6.jpg уже существует в d:\AVClassificator\dataset_temp\test\military truck, пропускаем.
# Файл image6.jpg уже существует в d:\AVClassificator\dataset_temp\test\military truck, пропускаем.
# Файл image6.jpg уже существует в d:\AVClassificator\dataset_temp\test\military truck, пропускаем.
# Файл image7.jpg уже существует в d:\AVClassificator\dataset_temp\test\military truck, пропускаем.
# Файл image7.jpg уже существует в d:\AVClassificator\dataset_temp\test\military truck, пропускаем.
# Файл image7.jpg уже существует в d:\AVClassificator\dataset_temp\test\military truck, пропускаем.
# Файл image7.jpg уже существует в d:\AVClassificator\dataset_temp\test\military truck, пропускаем.
# Файл image7.jpg уже существует в d:\AVClassificator\dataset_temp\test\military truck, пропускаем.
# Файл image7.jpg уже существует в d:\AVClassificator\dataset_temp\test\military truck, пропускаем.
# Файл image7.jpg уже существует в d:\AVClassificator\dataset_temp\test\military truck, пропускаем.
# Файл image7.jpg уже существует в d:\AVClassificator\dataset_temp\test\military truck, пропускаем.
# Файл image7.jpg уже существует в d:\AVClassificator\dataset_temp\test\military truck, пропускаем.
# Файл image7.jpg уже существует в d:\AVClassificator\dataset_temp\test\military truck, пропускаем.
# Файл image7.jpg уже существует в d:\AVClassificator\dataset_temp\test\military truck, пропускаем.
# Файл image9.jpg уже существует в d:\AVClassificator\dataset_temp\test\civilian car, пропускаем.
# Файл image9.jpg уже существует в d:\AVClassificator\dataset_temp\test\civilian car, пропускаем.
# Файл image9.jpg уже существует в d:\AVClassificator\dataset_temp\test\civilian car, пропускаем.
# Файл image9.jpg уже существует в d:\AVClassificator\dataset_temp\test\civilian car, пропускаем.
# Файл images205(5).jpg уже существует в d:\AVClassificator\dataset_temp\test\military aircraft, пропускаем.
# Файл images205(5).jpg уже существует в d:\AVClassificator\dataset_temp\test\military aircraft, пропускаем.
# Файл images205(5).jpg уже существует в d:\AVClassificator\dataset_temp\test\military aircraft, пропускаем.
# Файл images205(5).jpg уже существует в d:\AVClassificator\dataset_temp\test\military aircraft, пропускаем.
# Файл images205(5).jpg уже существует в d:\AVClassificator\dataset_temp\test\military aircraft, пропускаем.
# Файл images205(5).jpg уже существует в d:\AVClassificator\dataset_temp\test\military aircraft, пропускаем.
# Файл images205(5).jpg уже существует в d:\AVClassificator\dataset_temp\test\military aircraft, пропускаем.
# Файл images208(6).jpg уже существует в d:\AVClassificator\dataset_temp\test\military helicopter, пропускаем.
# Файл images208(6).jpg уже существует в d:\AVClassificator\dataset_temp\test\military helicopter, пропускаем.
# Файл images208(6).jpg уже существует в d:\AVClassificator\dataset_temp\test\military helicopter, пропускаем.
# Файл images208(8).jpg уже существует в d:\AVClassificator\dataset_temp\test\civilian car, пропускаем.
# Файл images208(8).jpg уже существует в d:\AVClassificator\dataset_temp\test\civilian car, пропускаем.
# Файл images208(8).jpg уже существует в d:\AVClassificator\dataset_temp\test\civilian car, пропускаем.
# Файл images209(1).jpg уже существует в d:\AVClassificator\dataset_temp\test\military tank, пропускаем.
# Файл images209(1).jpg уже существует в d:\AVClassificator\dataset_temp\test\military tank, пропускаем.
# Файл images210(4).jpg уже существует в d:\AVClassificator\dataset_temp\test\military truck, пропускаем.
# Файл images212(6).jpg уже существует в d:\AVClassificator\dataset_temp\test\military helicopter, пропускаем.
# Файл images213(2).jpg уже существует в d:\AVClassificator\dataset_temp\test\military tank, пропускаем.
# Файл images213(5).jpg уже существует в d:\AVClassificator\dataset_temp\test\military aircraft, пропускаем.
# Файл images214(3).jpg уже существует в d:\AVClassificator\dataset_temp\test\military aircraft, пропускаем.
# Файл images215(4).jpg уже существует в d:\AVClassificator\dataset_temp\test\military truck, пропускаем.
# Файл images219(1).jpg уже существует в d:\AVClassificator\dataset_temp\test\military tank, пропускаем.
# Файл images220(1).jpg уже существует в d:\AVClassificator\dataset_temp\test\military tank, пропускаем.
# Файл images220(1).jpg уже существует в d:\AVClassificator\dataset_temp\test\military tank, пропускаем.
# Файл images220(1).jpg уже существует в d:\AVClassificator\dataset_temp\test\military tank, пропускаем.
# Файл images220(1).jpg уже существует в d:\AVClassificator\dataset_temp\test\military tank, пропускаем.
# Файл images220(1).jpg уже существует в d:\AVClassificator\dataset_temp\test\military tank, пропускаем.
# Файл images220(1).jpg уже существует в d:\AVClassificator\dataset_temp\test\military tank, пропускаем.
# Файл images220(1).jpg уже существует в d:\AVClassificator\dataset_temp\test\military tank, пропускаем.
# Файл images220(1).jpg уже существует в d:\AVClassificator\dataset_temp\test\military tank, пропускаем.
# Файл images220(1).jpg уже существует в d:\AVClassificator\dataset_temp\test\military tank, пропускаем.
# Файл images220(1).jpg уже существует в d:\AVClassificator\dataset_temp\test\military tank, пропускаем.
# Файл images220(1).jpg уже существует в d:\AVClassificator\dataset_temp\test\military tank, пропускаем.
# Файл images221(1).jpg уже существует в d:\AVClassificator\dataset_temp\test\military tank, пропускаем.
# Файл images221(4).jpg уже существует в d:\AVClassificator\dataset_temp\test\military truck, пропускаем.
# Файл images74(6).jpg уже существует в d:\AVClassificator\dataset_temp\test\military helicopter, пропускаем.
# Файл images74(6).jpg уже существует в d:\AVClassificator\dataset_temp\test\military helicopter, пропускаем.
# Файл images74(6).jpg уже существует в d:\AVClassificator\dataset_temp\test\military helicopter, пропускаем.
# Файл images75.jpg уже существует в d:\AVClassificator\dataset_temp\test\military truck, пропускаем.
# Файл images75.jpg уже существует в d:\AVClassificator\dataset_temp\test\military truck, пропускаем.
# Файл images75.jpg уже существует в d:\AVClassificator\dataset_temp\test\military truck, пропускаем.
# Файл images76(11).jpg уже существует в d:\AVClassificator\dataset_temp\test\military aircraft, пропускаем.
# Файл images76(11).jpg уже существует в d:\AVClassificator\dataset_temp\test\military aircraft, пропускаем.
# Файл images76(11).jpg уже существует в d:\AVClassificator\dataset_temp\test\military aircraft, пропускаем.
# Файл images76(11).jpg уже существует в d:\AVClassificator\dataset_temp\test\military aircraft, пропускаем.
# Файл images76(11).jpg уже существует в d:\AVClassificator\dataset_temp\test\military aircraft, пропускаем.
# Файл images76(11).jpg уже существует в d:\AVClassificator\dataset_temp\test\military aircraft, пропускаем.
# Файл images76(11).jpg уже существует в d:\AVClassificator\dataset_temp\test\military aircraft, пропускаем.
# Файл images76(11).jpg уже существует в d:\AVClassificator\dataset_temp\test\military aircraft, пропускаем.
# Файл images76.jpg уже существует в d:\AVClassificator\dataset_temp\test\military tank, пропускаем.
# Файл images76.jpg уже существует в d:\AVClassificator\dataset_temp\test\military tank, пропускаем.
# Файл images76.jpg уже существует в d:\AVClassificator\dataset_temp\test\military tank, пропускаем.
# Файл images77(5).jpg уже существует в d:\AVClassificator\dataset_temp\test\military helicopter, пропускаем.
# Файл images77(5).jpg уже существует в d:\AVClassificator\dataset_temp\test\military helicopter, пропускаем.
# Файл images77(9).jpg уже существует в d:\AVClassificator\dataset_temp\test\civilian car, пропускаем.
# Файл images77(9).jpg уже существует в d:\AVClassificator\dataset_temp\test\civilian car, пропускаем.
# Файл images77(9).jpg уже существует в d:\AVClassificator\dataset_temp\test\civilian car, пропускаем.
# Файл images77(9).jpg уже существует в d:\AVClassificator\dataset_temp\test\civilian car, пропускаем.
# Файл images78(6).jpg уже существует в d:\AVClassificator\dataset_temp\test\military helicopter, пропускаем.
# Файл images78(6).jpg уже существует в d:\AVClassificator\dataset_temp\test\military helicopter, пропускаем.
# Файл images79(4).jpg уже существует в d:\AVClassificator\dataset_temp\test\military truck, пропускаем.
# Файл images79(4).jpg уже существует в d:\AVClassificator\dataset_temp\test\military truck, пропускаем.
# Файл images79(4).jpg уже существует в d:\AVClassificator\dataset_temp\test\military truck, пропускаем.
# Файл images79(4).jpg уже существует в d:\AVClassificator\dataset_temp\test\military truck, пропускаем.
# Файл images79(6).jpg уже существует в d:\AVClassificator\dataset_temp\test\military helicopter, пропускаем.
# Файл images79(6).jpg уже существует в d:\AVClassificator\dataset_temp\test\military helicopter, пропускаем.
# Файл images80(2).jpg уже существует в d:\AVClassificator\dataset_temp\test\military tank, пропускаем.
# Файл images80(9).jpg уже существует в d:\AVClassificator\dataset_temp\test\civilian car, пропускаем.
# Файл images80(9).jpg уже существует в d:\AVClassificator\dataset_temp\test\civilian car, пропускаем.
# Файл images80(9).jpg уже существует в d:\AVClassificator\dataset_temp\test\civilian car, пропускаем.
# Файл images80(9).jpg уже существует в d:\AVClassificator\dataset_temp\test\civilian car, пропускаем.
# Файл images81(1).jpg уже существует в d:\AVClassificator\dataset_temp\test\military tank, пропускаем.
# Файл images81(11).jpg уже существует в d:\AVClassificator\dataset_temp\test\military aircraft, пропускаем.
# Файл images81(11).jpg уже существует в d:\AVClassificator\dataset_temp\test\military aircraft, пропускаем.
# Файл images81(11).jpg уже существует в d:\AVClassificator\dataset_temp\test\military aircraft, пропускаем.
# Файл images81(9).jpg уже существует в d:\AVClassificator\dataset_temp\test\civilian car, пропускаем.
# Файл images81(9).jpg уже существует в d:\AVClassificator\dataset_temp\test\civilian car, пропускаем.
# Файл images81(9).jpg уже существует в d:\AVClassificator\dataset_temp\test\civilian car, пропускаем.
# Файл images81(9).jpg уже существует в d:\AVClassificator\dataset_temp\test\civilian car, пропускаем.
# Файл images81(9).jpg уже существует в d:\AVClassificator\dataset_temp\test\civilian car, пропускаем.
# Файл images81(9).jpg уже существует в d:\AVClassificator\dataset_temp\test\civilian car, пропускаем.
# Файл images81(9).jpg уже существует в d:\AVClassificator\dataset_temp\test\civilian car, пропускаем.
# Файл images81(9).jpg уже существует в d:\AVClassificator\dataset_temp\test\civilian car, пропускаем.
# Файл images81(9).jpg уже существует в d:\AVClassificator\dataset_temp\test\civilian car, пропускаем.
# Файл images81(9).jpg уже существует в d:\AVClassificator\dataset_temp\test\civilian car, пропускаем.
# Файл images81(9).jpg уже существует в d:\AVClassificator\dataset_temp\test\civilian car, пропускаем.
# Файл images81(9).jpg уже существует в d:\AVClassificator\dataset_temp\test\civilian car, пропускаем.
# Файл images82(1).jpg уже существует в d:\AVClassificator\dataset_temp\test\military tank, пропускаем.
# Файл images82(1).jpg уже существует в d:\AVClassificator\dataset_temp\test\military tank, пропускаем.
# Файл images83(3).jpg уже существует в d:\AVClassificator\dataset_temp\test\military aircraft, пропускаем.
# Файл images83.jpg уже существует в d:\AVClassificator\dataset_temp\test\civilian car, пропускаем.
# Файл images84(1).jpg уже существует в d:\AVClassificator\dataset_temp\test\military tank, пропускаем.
# Файл images84(6).jpg уже существует в d:\AVClassificator\dataset_temp\test\military helicopter, пропускаем.
# Файл images84(6).jpg уже существует в d:\AVClassificator\dataset_temp\test\military helicopter, пропускаем.
# Файл images84(6).jpg уже существует в d:\AVClassificator\dataset_temp\test\military helicopter, пропускаем.
# Файл images84(6).jpg уже существует в d:\AVClassificator\dataset_temp\test\military helicopter, пропускаем.
# Файл images84(6).jpg уже существует в d:\AVClassificator\dataset_temp\test\military helicopter, пропускаем.
# Файл images84(6).jpg уже существует в d:\AVClassificator\dataset_temp\test\military helicopter, пропускаем.
# Файл images84(7).jpg уже существует в d:\AVClassificator\dataset_temp\test\military helicopter, пропускаем.
# Файл images85(11).jpg уже существует в d:\AVClassificator\dataset_temp\test\civilian aircraft, пропускаем.
# Файл images85(11).jpg уже существует в d:\AVClassificator\dataset_temp\test\civilian aircraft, пропускаем.
# Файл images85(9).jpg уже существует в d:\AVClassificator\dataset_temp\test\civilian car, пропускаем.
# Файл images86(2).jpg уже существует в d:\AVClassificator\dataset_temp\test\military tank, пропускаем.
# Файл images86(2).jpg уже существует в d:\AVClassificator\dataset_temp\test\military tank, пропускаем.
# Файл images86(4).jpg уже существует в d:\AVClassificator\dataset_temp\test\military truck, пропускаем.
# Файл images86(4).jpg уже существует в d:\AVClassificator\dataset_temp\test\military truck, пропускаем.
# Файл images86(5).jpg уже существует в d:\AVClassificator\dataset_temp\test\military aircraft, пропускаем.
# Файл _107715692_gettyimages-1159570665.jpg уже существует в d:\AVClassificator\dataset_temp\test\military tank, пропускаем.
# Файл _107715692_gettyimages-1159570665.jpg уже существует в d:\AVClassificator\dataset_temp\test\military tank, пропускаем.
# Файл _107715692_gettyimages-1159570665.jpg уже существует в d:\AVClassificator\dataset_temp\test\military tank, пропускаем.
# Изображения успешно скопированы с заданным разрешением в папки классов.
